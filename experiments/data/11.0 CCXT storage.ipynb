# %%
import qubx
from qubx import logger

# %qubxd

# %load_ext autoreload
# %autoreload 2

from qubx.core.lookups import lookup
from qubx.data.registry import StorageRegistry
from qubx.data.storages.multi import MultiStorage
# Out:
# ⠀⠀⡰⡖⠒⠒⢒⢦⠀⠀
# ⠀⢠⠃⠈⢆⣀⣎⣀⣱⡀  QUBX | Quantitative Backtesting Environment
# ⠀⢳⠒⠒⡞⠚⡄⠀⡰⠁         (c) 2025, ver. 3.17.2
# ⠀⠀⠱⣜⣀⣀⣈⣦⠃⠀⠀⠀
# <style> .cell-output-ipywidget-background { background-color: transparent !important; } :root { --jp-widgets-color: var(--vscode-editor-foreground); --jp-widgets-font-size: var(--vscode-editor-font-size); } .widget-hprogress, .jupyter-widget-hprogress { height: 16px; align-self: center; kj} table.dataframe, .dataframe td, .dataframe tr { border: 1px solid #55554a85; border-collapse: collapse; color: #859548d9 !important; } .dataframe th { border: 1px solid #55554a85; border-collapse: collapse; background-color: #010101 !important; color: #177 !important; } </style>

# %%
stor = StorageRegistry.get("ccxt")
r = stor.get_reader("BINANCE.UM", "SWAP")
r1 = stor.get_reader("HYPERLIQUID", "SWAP")

# %%
r.get_data_types("BTCUSDT")
# Out:
# [ohlc, funding_payment]

# %%
r.read("BTCUSDT", "ohlc(1h)", "-12h", "now").to_pd()
# Out:
#                         open     high      low    close     volume  \
# timestamp
# 2026-09-21 00:00:00  81144.0  81815.5  81135.1  81573.3  11910.397
# 2026-09-21 01:00:00  81573.1  82099.9  80819.4  80964.3  15290.906
# 2026-09-21 02:00:00  80964.3  81488.7  80909.7  81280.0   7034.507
# 2026-09-21 03:00:00  81279.9  81549.0  81211.0  81403.7   2531.479
# 2026-09-21 04:00:00  81403.7  81481.5  81199.9  81365.5   2378.238
# 2026-09-21 05:00:00  81365.5  81765.5  81271.0  81520.0   4060.532
# 2026-09-21 06:00:00  81520.0  81857.1  81356.0  81609.0   5580.807
# 2026-09-21 07:00:00  81609.1  81700.0  81433.2  81699.9   3337.296
# 2026-09-21 08:00:00  81700.0  84275.5  81697.2  83717.3  40829.826
# 2026-09-21 09:00:00  83717.3  85285.0  83660.4  84626.0  35913.342
# 2026-09-21 10:00:00  84625.9  84800.8  84100.3  84400.1  13667.001
# 2026-09-21 11:00:00  84400.2  84882.2  84350.8  84848.3   7342.118
#
#                      quote_volume
# timestamp
# 2026-09-21 00:00:00  9.715704e+08
# 2026-09-21 01:00:00  1.238018e+09
# 2026-09-21 02:00:00  5.717647e+08
# 2026-09-21 03:00:00  2.060718e+08
# 2026-09-21 04:00:00  1.935065e+08
# 2026-09-21 05:00:00  3.310146e+08
# 2026-09-21 06:00:00  4.554441e+08
# 2026-09-21 07:00:00  2.726567e+08
# 2026-09-21 08:00:00  3.418163e+09
# 2026-09-21 09:00:00  3.039202e+09
# 2026-09-21 10:00:00  1.153496e+09
# 2026-09-21 11:00:00  6.229662e+08

# %%
r1.read("BTCUSDC", "ohlc(1h)", "-3h", "now").to_pd()
# Out:
#                         open     high      low    close      volume  \
# timestamp
# 2026-09-21 09:00:00  83845.0  85500.0  83775.0  84735.0  6272.33769
# 2026-09-21 10:00:00  84734.0  84900.0  84165.0  84478.0  3593.74845
# 2026-09-21 11:00:00  84477.0  84947.0  84432.0  84919.0  1168.42382
#
#                      quote_volume
# timestamp
# 2026-09-21 09:00:00  5.314865e+08
# 2026-09-21 10:00:00  3.035927e+08
# 2026-09-21 11:00:00  9.922138e+07

# %%
r.read("BTCUSDT", "funding_payment", "-1d", "now").to_pd()
# Out:
#                          funding_rate  funding_interval_hours
# timestamp
# 2026-09-20 08:06:12.894      0.000075                8.000002
# 2026-09-20 23:56:53.547      0.000042                7.999999
# 2026-09-21 07:56:53.544      0.000100                7.999999

# %%
r1.read("BTCUSDC", "funding_payment", "-1d", "now").to_pd()
# Out:
#                          funding_rate  funding_interval_hours
# timestamp
# 2026-09-20 11:45:43.860      0.000013                1.000006
# 2026-09-20 12:36:49.122      0.000013                0.999989
# 2026-09-20 13:39:26.352      0.000013                1.000003
# 2026-09-20 14:43:25.602      0.000013                0.999999
# 2026-09-20 15:43:06.676      0.000013                0.999991
# 2026-09-20 16:41:44.664      0.000013                1.000009
# 2026-09-20 17:32:49.875      0.000013                0.999993
# 2026-09-20 18:33:27.534      0.000013                1.000009
# 2026-09-20 19:22:52.020      0.000013                1.000003
# 2026-09-20 20:41:07.008      0.000013                0.999993
# 2026-09-20 22:00:00.000      0.000013                1.000000
# 2026-09-20 22:23:10.839      0.000013                1.000011
# 2026-09-20 23:30:50.220      0.000013                0.999995
# 2026-09-21 00:57:41.336      0.000013                0.999994
# 2026-09-21 01:32:49.675      0.000013                0.999993
# 2026-09-21 02:42:03.726      0.000013                1.000018
# 2026-09-21 03:26:12.360      0.000013                0.999983
# 2026-09-21 04:25:10.656      0.000013                1.000009
# 2026-09-21 05:49:43.278      0.000013                1.000002
# 2026-09-21 06:02:18.642      0.000013                1.000006
# 2026-09-21 07:33:08.860      0.000013                1.000001
# 2026-09-21 08:57:21.576      0.000028                0.999986
# 2026-09-21 09:29:09.870      0.000090                1.000005
# 2026-09-21 10:29:09.888      0.000023                1.000005

# %%
stor1 = StorageRegistry.get("ccxt")
stor2 = StorageRegistry.get("qdb::quantlab")

# %%
s2 = MultiStorage(storages=[stor1, stor2])
rx = s2.get_reader("BINANCE.UM", "SWAP")

# %%
# %%time
rx.read(["BTCUSDT", "ETHUSDT"], "ohlc(1min)", "-2d", "now").to_pd()
# Out:
# CPU times: user 14.2 s, sys: 69.4 ms, total: 14.2 s
# Wall time: 19.4 s
#                      BTCUSDT                                      \
#                         open     high      low    close   volume
# timestamp
# 2026-09-19 13:27:00  81255.8  81255.9  81232.7  81232.7    9.285
# 2026-09-19 13:28:00  81232.8  81232.8  81191.4  81191.5   34.490
# 2026-09-19 13:29:00  81191.4  81200.1  81191.4  81200.1   16.241
# 2026-09-19 13:30:00  81200.1  81200.1  81160.3  81165.9   71.661
# 2026-09-19 13:31:00  81166.0  81238.4  81166.0  81225.8   82.862
# ...                      ...      ...      ...      ...      ...
# 2026-09-21 13:22:00  85129.2  85180.0  85105.9  85106.0  107.931
# 2026-09-21 13:23:00  85106.0  85122.7  85060.0  85060.0  126.982
# 2026-09-21 13:24:00  85060.0  85077.7  85037.6  85037.6  142.292
# 2026-09-21 13:25:00  85037.6  85052.8  84964.3  85043.6  526.336
# 2026-09-21 13:26:00  85043.6  85105.8  85010.0  85010.0   73.600
#
#                                    ETHUSDT                             \
#                      quote_volume     open     high      low    close
# timestamp
# 2026-09-19 13:27:00  7.543334e+05  2635.33  2635.51  2634.03  2634.04
# 2026-09-19 13:28:00  2.800886e+06  2634.04  2634.04  2632.20  2632.20
# 2026-09-19 13:29:00  1.318685e+06  2632.21  2633.52  2632.00  2633.51
# 2026-09-19 13:30:00  5.816616e+06  2633.52  2633.52  2626.30  2629.51
# 2026-09-19 13:31:00  6.728686e+06  2629.50  2635.33  2629.50  2634.75
# ...                           ...      ...      ...      ...      ...
# 2026-09-21 13:22:00  9.185576e+06  2736.64  2738.88  2735.16  2735.64
# 2026-09-21 13:23:00  1.080109e+07  2735.64  2737.04  2733.78  2733.79
# 2026-09-21 13:24:00  1.210017e+07  2733.78  2734.67  2732.00  2732.80
# 2026-09-21 13:25:00  4.476151e+07  2732.80  2733.23  2728.00  2730.60
# 2026-09-21 13:26:00  6.256736e+06  2730.61  2733.15  2727.76  2727.97
#
#
#                         volume  quote_volume
# timestamp
# 2026-09-19 13:27:00    731.610  1.927784e+06
# 2026-09-19 13:28:00   1890.569  4.978376e+06
# 2026-09-19 13:29:00   1934.204  5.091620e+06
# 2026-09-19 13:30:00  15174.853  3.989615e+07
# 2026-09-19 13:31:00   4791.928  1.261325e+07
# ...                        ...           ...
# 2026-09-21 13:22:00   2054.445  5.620222e+06
# 2026-09-21 13:23:00   2719.114  7.433487e+06
# 2026-09-21 13:24:00   3972.650  1.085646e+07
# 2026-09-21 13:25:00   6326.926  1.727630e+07
# 2026-09-21 13:26:00   1523.029  4.154777e+06
#
# [2880 rows x 12 columns]

# %%
rx.read("BTCUSDT", "funding_payment", "-3d", "now").to_pd()
# Out:
#                          funding_rate  funding_interval_hours
# timestamp
# 2026-09-18 16:00:00.000      0.000068                8.000000
# 2026-09-18 16:02:04.288      0.000066                8.000001
# 2026-09-19 00:00:00.000      0.000066                8.000000
# 2026-09-19 07:57:55.708      0.000100                7.999999
# 2026-09-19 08:00:00.000      0.000100                8.000000
# 2026-09-19 16:00:00.000      0.000100                8.000000
# 2026-09-20 00:00:00.000      0.000100                8.000000
# 2026-09-20 08:00:00.000      0.000100                8.000000
# 2026-09-20 08:06:12.894      0.000075                8.000002
# 2026-09-20 16:00:00.000      0.000076                8.000000
# 2026-09-20 23:56:53.547      0.000042                7.999999
# 2026-09-21 07:56:53.544      0.000100                7.999999

# %% [markdown]
# ### Misc tests

# %%
stor = StorageRegistry.get("qdb::quantlab")
r = stor.get_reader("GATEIO.F", "SWAP")
w = r.read("BTCUSDT", "funding_payment", "2026-01-10 00:00:00", "2026-02-20 00:00:00", chunksize=100)
# w
# next(w)

# %%
fr = stor.get_reader("BINANCE.UM", "SWAP")

# %%
# fundamental = fr.read(["BTCUSDT"], "funding_payment", "2026-01-01", "2026-01-10").to_pd(False)

funding_payments = fr.read([], "funding_payment", "2026-01-01", "2026-01-10").to_pd(True)
# if funding_payments is None or funding_payments.empty:
    # return []
earliest_payment_time = funding_payments.reset_index().groupby("symbol")["timestamp"].min()
earliest_payment_time = earliest_payment_time[
    earliest_payment_time <= min_maturity_date + pd.Timedelta(hours=10)
]  # type: ignore

# %%
funding_payments
# Out:
#                                     funding_rate  funding_interval_hours
# timestamp           symbol
# 2026-01-01 00:00:00 0GUSDT             -0.001422                     4.0
#                     1000000BOBUSDT      0.002340                     4.0
#                     1000000MOGUSDT      0.000050                     4.0
#                     1000BONKUSDC        0.000050                     4.0
#                     1000BONKUSDT        0.000020                     4.0
# ...                                          ...                     ...
# 2026-01-09 23:00:00 FLOWUSDT           -0.000305                     1.0
#                     GMTUSDT            -0.000454                     8.0
#                     PIPPINUSDT         -0.000542                     1.0
#                     RIVERUSDT           0.000230                     1.0
#                     ZKPUSDT            -0.000085                     1.0
#
# [28598 rows x 2 columns]

# %%
earliest_payment_time
# Out:
# symbol
# 0GUSDT           2026-01-01
# 1000000BOBUSDT   2026-01-01
# 1000000MOGUSDT   2026-01-01
# 1000BONKUSDC     2026-01-01
# 1000BONKUSDT     2026-01-01
#                     ...
# ZORAUSDT         2026-01-01
# ZRCUSDT          2026-01-01
# ZROUSDT          2026-01-01
# ZRXUSDT          2026-01-01
# 币安人生USDT         2026-01-01
# Name: timestamp, Length: 580, dtype: datetime64[us]

# %%
fundamental
# Out:
#                      BTCUSDT
#                       symbol funding_rate funding_interval_hours
# timestamp
# 2026-01-01 00:00:00  BTCUSDT     0.000100                    8.0
# 2026-01-01 08:00:00  BTCUSDT     0.000100                    8.0
# 2026-01-01 16:00:00  BTCUSDT     0.000018                    8.0
# 2026-01-02 00:00:00  BTCUSDT     0.000056                    8.0
# 2026-01-02 08:00:00  BTCUSDT     0.000042                    8.0
# 2026-01-02 16:00:00  BTCUSDT     0.000048                    8.0
# 2026-01-03 00:00:00  BTCUSDT     0.000031                    8.0
# 2026-01-03 08:00:00  BTCUSDT     0.000011                    8.0
# 2026-01-03 16:00:00  BTCUSDT     0.000069                    8.0
# 2026-01-04 00:00:00  BTCUSDT     0.000095                    8.0
# 2026-01-04 08:00:00  BTCUSDT     0.000058                    8.0
# 2026-01-04 16:00:00  BTCUSDT     0.000044                    8.0
# 2026-01-05 00:00:00  BTCUSDT     0.000089                    8.0
# 2026-01-05 08:00:00  BTCUSDT     0.000052                    8.0
# 2026-01-05 16:00:00  BTCUSDT     0.000078                    8.0
# 2026-01-06 00:00:00  BTCUSDT    -0.000014                    8.0
# 2026-01-06 08:00:00  BTCUSDT     0.000028                    8.0
# 2026-01-06 16:00:00  BTCUSDT     0.000027                    8.0
# 2026-01-07 00:00:00  BTCUSDT     0.000066                    8.0
# 2026-01-07 08:00:00  BTCUSDT     0.000100                    8.0
# 2026-01-07 16:00:00  BTCUSDT     0.000029                    8.0
# 2026-01-08 00:00:00  BTCUSDT     0.000087                    8.0
# 2026-01-08 08:00:00  BTCUSDT     0.000100                    8.0
# 2026-01-08 16:00:00  BTCUSDT     0.000064                    8.0
# 2026-01-09 00:00:00  BTCUSDT    -0.000028                    8.0
# 2026-01-09 08:00:00  BTCUSDT     0.000073                    8.0
# 2026-01-09 16:00:00  BTCUSDT     0.000002                    8.0

# %%
mcap = fundamental.xs("market_cap", axis=1, level=1).mean(axis=0).sort_values(ascending=False)

# %%
mcap.index
# Out:
# Index(['BTC', 'ETH', 'USDT', 'XRP', 'BNB', 'SOL', 'USDC', 'TRX', 'DOGE', 'ADA',
#        ...
#        'ORD', '1MBABYDOGE', 'HIGH', 'AEUR', 'EURI', 'MKR', 'AGT', 'FTM', 'HIP',
#        'FTT'],
#       dtype='object', length=865)

# %%
fundamental.xs(("asset", "market_cap"), axis=1)

# %%
next(w).to_records()[0].time

# %%
stor = StorageRegistry.get("qdb::quantlab")
r = stor.get_reader("BINANCE.UM", "SWAP")

# %%
r.read("ADAUSDT", "ohlc(1d)", "120d", "2020-02-01 00:00:00.000").to_pd()
# Out:
#              symbol    open     high      low    close       volume  \
# timestamp
# 2020-01-31  ADAUSDT  0.0545  0.05559  0.05209  0.05387  244632624.0
#
#             quote_volume  count  taker_buy_volume  taker_buy_quote_volume
# timestamp
# 2020-01-31    13130602.0  40186       116954448.0               6287357.0
